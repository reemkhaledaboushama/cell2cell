# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import *
from sklearn import neighbors, datasets
from sklearn.metrics import precision_score, recall_score, f1_score, precision_recall_curve, roc_curve, roc_auc_score, auc, accuracy_score
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#Function to plot precision/recall tradeoff curve
def plot_precision_recall_vs_thresholds(precisions, recalls, thresholds):
    plt.plot(thresholds, precisions[:-1], "b--", label="Precision")
    plt.plot(thresholds, recalls[:-1], "g--", label="Recall")
    plt.xlabel("Threshold")
    plt.title('Precision/Recall Curve')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.grid(b=True, which="both", axis="both", color='gray', linestyle='-', linewidth=1)
    plt.show()

# %%
#Function to plot ROC curve
def plot_ROC(fpr, tpr, roc_auc):
    plt.plot(fpr, tpr, label='ROC curve (area = %0.3f)' % roc_auc)
    plt.plot([0, 1], [0, 1], 'k--')  # random predictions curve
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.0])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.legend(loc="lower right")

# %%
data = pd.read_csv(r'dataset//cell2celltrain.csv', delimiter = ",",  header = 0, index_col = 0)

# %%
data.describe()
# Out:
#        MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# count    50891.000000    50891.000000          50891.000000
# mean        58.834492      525.653416             46.830088
# std         44.507336      529.871063             23.848871
# min         -6.170000        0.000000            -11.000000
# 25%         33.610000      158.000000             30.000000
# 50%         48.460000      366.000000             45.000000
# 75%         71.065000      723.000000             60.000000
# max       1223.380000     7359.000000            400.000000
#
#        DirectorAssistedCalls  OverageMinutes  RoamingCalls  PercChangeMinutes  \
# count           50891.000000    50891.000000  50891.000000       50680.000000
# mean                0.895229       40.027785      1.236244         -11.547908
# std                 2.228546       96.588076      9.818294         257.514772
# min                 0.000000        0.000000      0.000000       -3875.000000
# 25%                 0.000000        0.000000      0.000000         -83.000000
# 50%                 0.250000        3.000000      0.000000          -5.000000
# 75%                 0.990000       41.000000      0.300000          66.000000
# max               159.390000     4321.000000   1112.400000        5192.000000
#
#        PercChangeRevenues  DroppedCalls  BlockedCalls  ...      Handsets  \
# count        50680.000000  51047.000000  51047.000000  ...  51046.000000
# mean            -1.191985      6.011489      4.085672  ...      1.805646
# std             39.574915      9.043955     10.946905  ...      1.331173
# min          -1107.700000      0.000000      0.000000  ...      1.000000
# 25%             -7.100000      0.700000      0.000000  ...      1.000000
# 50%             -0.300000      3.000000      1.000000  ...      1.000000
# 75%              1.600000      7.700000      3.700000  ...      2.000000
# max           2483.500000    221.700000    384.300000  ...     24.000000
#
#        HandsetModels  CurrentEquipmentDays        AgeHH1        AgeHH2  \
# count   51046.000000          51046.000000  50138.000000  50138.000000
# mean        1.558751            380.545841     31.338127     21.144142
# std         0.905932            253.801982     22.094635     23.931368
# min         1.000000             -5.000000      0.000000      0.000000
# 25%         1.000000            205.000000      0.000000      0.000000
# 50%         1.000000            329.000000     36.000000      0.000000
# 75%         2.000000            515.000000     48.000000     42.000000
# max        15.000000           1812.000000     99.000000     99.000000
#
#        RetentionCalls  RetentionOffersAccepted  ReferralsMadeBySubscriber  \
# count    51047.000000             51047.000000               51047.000000
# mean         0.037201                 0.018277                   0.052070
# std          0.206483                 0.142458                   0.307592
# min          0.000000                 0.000000                   0.000000
# 25%          0.000000                 0.000000                   0.000000
# 50%          0.000000                 0.000000                   0.000000
# 75%          0.000000                 0.000000                   0.000000
# max          4.000000                 3.000000                  35.000000
#
#         IncomeGroup  AdjustmentsToCreditRating
# count  51047.000000               51047.000000
# mean       4.324524                   0.053911
# std        3.138236                   0.383147
# min        0.000000                   0.000000
# 25%        0.000000                   0.000000
# 50%        5.000000                   0.000000
# 75%        7.000000                   0.000000
# max        9.000000                  25.000000
#
# [8 rows x 34 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51047 entries, 3000002 to 3399994
# Data columns (total 57 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Churn                      51047 non-null  object
#  1   MonthlyRevenue             50891 non-null  float64
#  2   MonthlyMinutes             50891 non-null  float64
#  3   TotalRecurringCharge       50891 non-null  float64
#  4   DirectorAssistedCalls      50891 non-null  float64
#  5   OverageMinutes             50891 non-null  float64
#  6   RoamingCalls               50891 non-null  float64
#  7   PercChangeMinutes          50680 non-null  float64
#  8   PercChangeRevenues         50680 non-null  float64
#  9   DroppedCalls               51047 non-null  float64
#  10  BlockedCalls               51047 non-null  float64
#  11  UnansweredCalls            51047 non-null  float64
#  12  CustomerCareCalls          51047 non-null  float64
#  13  ThreewayCalls              51047 non-null  float64
#  14  ReceivedCalls              51047 non-null  float64
#  15  OutboundCalls              51047 non-null  float64
#  16  InboundCalls               51047 non-null  float64
#  17  PeakCallsInOut             51047 non-null  float64
#  18  OffPeakCallsInOut          51047 non-null  float64
#  19  DroppedBlockedCalls        51047 non-null  float64
#  20  CallForwardingCalls        51047 non-null  float64
#  21  CallWaitingCalls           51047 non-null  float64
#  22  MonthsInService            51047 non-null  int64
#  23  UniqueSubs                 51047 non-null  int64
#  24  ActiveSubs                 51047 non-null  int64
#  25  ServiceArea                51023 non-null  object
#  26  Handsets                   51046 non-null  float64
#  27  HandsetModels              51046 non-null  float64
#  28  CurrentEquipmentDays       51046 non-null  float64
#  29  AgeHH1                     50138 non-null  float64
#  30  AgeHH2                     50138 non-null  float64
#  31  ChildrenInHH               51047 non-null  object
#  32  HandsetRefurbished         51047 non-null  object
#  33  HandsetWebCapable          51047 non-null  object
#  34  TruckOwner                 51047 non-null  object
#  35  RVOwner                    51047 non-null  object
#  36  Homeownership              51047 non-null  object
#  37  BuysViaMailOrder           51047 non-null  object
#  38  RespondsToMailOffers       51047 non-null  object
#  39  OptOutMailings             51047 non-null  object
#  40  NonUSTravel                51047 non-null  object
#  41  OwnsComputer               51047 non-null  object
#  42  HasCreditCard              51047 non-null  object
#  43  RetentionCalls             51047 non-null  int64
#  44  RetentionOffersAccepted    51047 non-null  int64
#  45  NewCellphoneUser           51047 non-null  object
#  46  NotNewCellphoneUser        51047 non-null  object
#  47  ReferralsMadeBySubscriber  51047 non-null  int64
#  48  IncomeGroup                51047 non-null  int64
#  49  OwnsMotorcycle             51047 non-null  object
#  50  AdjustmentsToCreditRating  51047 non-null  int64
#  51  HandsetPrice               51047 non-null  object
#  52  MadeCallToRetentionTeam    51047 non-null  object
#  53  CreditRating               51047 non-null  object
#  54  PrizmCode                  51047 non-null  object
#  55  Occupation                 51047 non-null  object
#  56  MaritalStatus              51047 non-null  object
# dtypes: float64(26), int64(8), object(23)
# memory usage: 22.6+ MB

# %%
categorical = []
continuous = []

for column in data.columns:
    print(data[column].value_counts())
    print(data[column].shape)
    print(f"unique: {len(data[column].unique())}")
    print(f"null:{data[column].isnull().sum()}")
    if len(data[column].unique()) < 20:
        categorical.append(column)
 
    else:
        continuous.append(column)
    #sns.boxplot(data[column].dropna())
    print("________________________________________________________________")

categorical_features = data[categorical]
continuous_features = data[continuous]
# Out:
# Churn
# No     36336
# Yes    14711
# Name: count, dtype: int64
# (51047,)
# unique: 2
# null:0
# ________________________________________________________________
# MonthlyRevenue
# 29.99     1069
# 34.99      806
# 10.00      469
# 30.00      404
# 49.99      392
#           ...
# 118.03       1
# 230.65       1
# 194.90       1
# 119.77       1
# 109.96       1
# Name: count, Length: 12665, dtype: int64
# (51047,)
# unique: 12666
# null:156
# ________________________________________________________________
# MonthlyMinutes
# 0.0       723
# 2.0       138
# 8.0       127
# 6.0       122
# 88.0      116
#          ...
# 2252.0      1
# 2391.0      1
# 3129.0      1
# 4578.0      1
# 2437.0      1
# Name: count, Length: 2719, dtype: int64
# (51047,)
# unique: 2720
# null:156
# ________________________________________________________________
# TotalRecurringCharge
# 30.0     7302
# 45.0     6630
# 60.0     4435
# 40.0     4415
# 50.0     4143
#          ...
# 149.0       1
# 302.0       1
# 281.0       1
# 207.0       1
# 212.0       1
# Name: count, Length: 214, dtype: int64
# (51047,)
# unique: 215
# null:156
# ________________________________________________________________
# DirectorAssistedCalls
# 0.00     24512
# 0.25      6757
# 0.50      3948
# 0.74      2748
# 0.99      1993
#          ...
# 5.28         1
# 45.05        1
# 18.32        1
# 32.17        1
# 9.57         1
# Name: count, Length: 146, dtype: int64
# (51047,)
# unique: 147
# null:156
# ________________________________________________________________
# OverageMinutes
# 0.0       23262
# 2.0        1088
# 1.0        1018
# 4.0         847
# 6.0         693
#           ...
# 741.0         1
# 604.0         1
# 412.0         1
# 409.0         1
# 2018.0        1
# Name: count, Length: 746, dtype: int64
# (51047,)
# unique: 747
# null:156
# ________________________________________________________________
# RoamingCalls
# 0.0      34947
# 0.2       1744
# 0.1       1444
# 0.3       1177
# 0.5        836
#          ...
# 48.2         1
# 92.1         1
# 330.2        1
# 52.4         1
# 55.6         1
# Name: count, Length: 530, dtype: int64
# (51047,)
# unique: 531
# null:156
# ________________________________________________________________
# PercChangeMinutes
#  0.0       1124
# -2.0        430
# -4.0        369
# -8.0        346
#  2.0        338
#            ...
# -1509.0       1
# -863.0        1
# -1087.0       1
#  1358.0       1
#  1578.0       1
# Name: count, Length: 2262, dtype: int64
# (51047,)
# unique: 2263
# null:367
# ________________________________________________________________
# PercChangeRevenues
#  0.0      5818
# -0.2      1497
# -0.3      1365
# -0.5       883
# -0.4       697
#           ...
#  401.5       1
# -134.6       1
#  115.3       1
#  372.5       1
# -253.9       1
# Name: count, Length: 2899, dtype: int64
# (51047,)
# unique: 2900
# null:367
# ________________________________________________________________
# DroppedCalls
# 0.0      7738
# 0.7      2615
# 0.3      2540
# 1.3      2294
# 1.0      2290
#          ...
# 9.5         1
# 83.3        1
# 87.3        1
# 98.7        1
# 101.7       1
# Name: count, Length: 285, dtype: int64
# (51047,)
# unique: 285
# null:0
# ________________________________________________________________
# BlockedCalls
# 0.0      13912
# 0.3       5254
# 0.7       4526
# 1.0       2966
# 1.3       2633
#          ...
# 139.0        1
# 174.3        1
# 147.7        1
# 124.0        1
# 103.7        1
# Name: count, Length: 373, dtype: int64
# (51047,)
# unique: 373
# null:0
# ________________________________________________________________
# UnansweredCalls
# 0.0      4990
# 0.7       607
# 1.3       579
# 0.3       550
# 2.0       550
#          ...
# 330.7       1
# 370.0       1
# 259.7       1
# 263.0       1
# 287.0       1
# Name: count, Length: 840, dtype: int64
# (51047,)
# unique: 840
# null:0
# ________________________________________________________________
# CustomerCareCalls
# 0.0      28020
# 0.3       3613
# 0.7       2736
# 1.0       1785
# 1.3       1616
#          ...
# 93.0         1
# 273.0        1
# 75.0         1
# 52.7         1
# 132.3        1
# Name: count, Length: 185, dtype: int64
# (51047,)
# unique: 185
# null:0
# ________________________________________________________________
# ThreewayCalls
# 0.0     37133
# 0.3      6109
# 0.7      3183
# 1.0      1388
# 1.3       896
#         ...
# 30.3        1
# 66.0        1
# 26.0        1
# 19.3        1
# 65.3        1
# Name: count, Length: 78, dtype: int64
# (51047,)
# unique: 78
# null:0
# ________________________________________________________________
# ReceivedCalls
# 0.0       6337
# 0.1        241
# 0.2        225
# 0.3        183
# 0.6        164
#           ...
# 855.8        1
# 658.7        1
# 875.5        1
# 738.0        1
# 1225.3       1
# Name: count, Length: 6121, dtype: int64
# (51047,)
# unique: 6121
# null:0
# ________________________________________________________________
# OutboundCalls
# 0.0      6428
# 0.3       944
# 0.7       903
# 1.3       717
# 1.0       713
#          ...
# 277.3       1
# 325.3       1
# 313.7       1
# 232.7       1
# 430.3       1
# Name: count, Length: 787, dtype: int64
# (51047,)
# unique: 787
# null:0
# ________________________________________________________________
# InboundCalls
# 0.0      14999
# 0.3       2883
# 0.7       2390
# 1.0       1657
# 1.3       1557
#          ...
# 137.3        1
# 270.0        1
# 131.7        1
# 190.0        1
# 163.7        1
# Name: count, Length: 472, dtype: int64
# (51047,)
# unique: 472
# null:0
# ________________________________________________________________
# PeakCallsInOut
# 0.0       4224
# 0.3        194
# 0.7        164
# 2.7        159
# 3.3        143
#           ...
# 465.0        1
# 692.0        1
# 665.7        1
# 547.0        1
# 1359.0       1
# Name: count, Length: 1839, dtype: int64
# (51047,)
# unique: 1839
# null:0
# ________________________________________________________________
# OffPeakCallsInOut
# 0.0      4547
# 0.7       333
# 1.3       305
# 2.7       298
# 0.3       291
#          ...
# 461.0       1
# 350.3       1
# 747.3       1
# 811.7       1
# 910.3       1
# Name: count, Length: 1669, dtype: int64
# (51047,)
# unique: 1669
# null:0
# ________________________________________________________________
# DroppedBlockedCalls
# 0.0      5793
# 1.3      1506
# 0.7      1492
# 2.0      1441
# 0.3      1379
#          ...
# 171.0       1
# 288.3       1
# 108.7       1
# 161.0       1
# 99.0        1
# Name: count, Length: 447, dtype: int64
# (51047,)
# unique: 447
# null:0
# ________________________________________________________________
# CallForwardingCalls
# 0.0     50813
# 0.3       101
# 0.7        50
# 1.0        18
# 2.0        13
# 1.3        11
# 2.3         8
# 1.7         5
# 3.7         3
# 2.7         2
# 4.0         2
# 5.0         2
# 55.7        1
# 21.0        1
# 5.3         1
# 3.0         1
# 12.0        1
# 81.3        1
# 22.0        1
# 10.7        1
# 8.7         1
# 26.3        1
# 11.0        1
# 31.3        1
# 6.3         1
# 33.7        1
# 16.0        1
# 9.7         1
# 51.7        1
# 23.7        1
# 12.3        1
# Name: count, dtype: int64
# (51047,)
# unique: 31
# null:0
# ________________________________________________________________
# CallWaitingCalls
# 0.0      25029
# 0.3       5427
# 0.7       3759
# 1.0       2316
# 1.3       1872
#          ...
# 63.0         1
# 80.0         1
# 64.3         1
# 105.3        1
# 86.3         1
# Name: count, Length: 223, dtype: int64
# (51047,)
# unique: 223
# null:0
# ________________________________________________________________
# MonthsInService
# 11    3599
# 7     2821
# 12    2737
# 13    2719
# 9     2477
# 10    2381
# 14    2291
# 8     2214
# 19    2004
# 15    1871
# 23    1836
# 21    1809
# 16    1778
# 17    1749
# 25    1611
# 18    1509
# 20    1413
# 22    1269
# 24    1174
# 26    1022
# 27     935
# 29     899
# 31     863
# 6      746
# 28     741
# 33     717
# 30     700
# 35     685
# 32     589
# 34     543
# 37     466
# 36     425
# 38     286
# 39     240
# 41     210
# 40     175
# 43     174
# 42     151
# 45     144
# 44     140
# 47     124
# 48     117
# 49     111
# 46     110
# 53      90
# 50      84
# 51      64
# 52      57
# 54      50
# 55      43
# 57      25
# 56      20
# 59      20
# 58      11
# 60       7
# 61       1
# Name: count, dtype: int64
# (51047,)
# unique: 56
# null:0
# ________________________________________________________________
# UniqueSubs
# 1      32109
# 2      13852
# 3       3212
# 4       1219
# 5        421
# 6        147
# 7         49
# 9         12
# 8         10
# 10         6
# 12         3
# 11         3
# 13         2
# 18         1
# 196        1
# Name: count, dtype: int64
# (51047,)
# unique: 15
# null:0
# ________________________________________________________________
# ActiveSubs
# 1     36267
# 2     12223
# 3      1907
# 4       444
# 5       144
# 0        39
# 6        13
# 8         5
# 7         2
# 9         1
# 53        1
# 11        1
# Name: count, dtype: int64
# (51047,)
# unique: 12
# null:0
# ________________________________________________________________
# ServiceArea
# NYCBRO917    1684
# HOUHOU281    1510
# DALDAL214    1498
# NYCMAN917    1182
# APCFCH703     783
#              ...
# OHIRAV330       1
# OMANEW515       1
# KCYHES316       1
# AIRGEO843       1
# NCRDNN910       1
# Name: count, Length: 747, dtype: int64
# (51047,)
# unique: 748
# null:24
# ________________________________________________________________
# Handsets
# 1.0     28852
# 2.0     12708
# 3.0      5072
# 4.0      2232
# 5.0      1033
# 6.0       487
# 7.0       297
# 8.0       147
# 9.0        82
# 10.0       38
# 11.0       35
# 12.0       19
# 13.0       16
# 14.0        7
# 16.0        5
# 15.0        3
# 19.0        3
# 17.0        3
# 24.0        2
# 18.0        2
# 21.0        1
# 22.0        1
# 20.0        1
# Name: count, dtype: int64
# (51047,)
# unique: 24
# null:1
# ________________________________________________________________
# HandsetModels
# 1.0     31881
# 2.0     13028
# 3.0      4129
# 4.0      1278
# 5.0       449
# 6.0       173
# 7.0        59
# 8.0        24
# 9.0        16
# 10.0        6
# 11.0        1
# 15.0        1
# 14.0        1
# Name: count, dtype: int64
# (51047,)
# unique: 14
# null:1
# ________________________________________________________________
# CurrentEquipmentDays
# 202.0     159
# 313.0     156
# 212.0     149
# 199.0     147
# 308.0     147
#          ...
# 1438.0      1
# 1381.0      1
# 1443.0      1
# 1276.0      1
# 1219.0      1
# Name: count, Length: 1438, dtype: int64
# (51047,)
# unique: 1439
# null:1
# ________________________________________________________________
# AgeHH1
# 0.0     13917
# 46.0     2149
# 42.0     2074
# 50.0     2063
# 48.0     2055
# 44.0     2037
# 40.0     1979
# 52.0     1968
# 38.0     1967
# 36.0     1889
# 30.0     1875
# 32.0     1826
# 34.0     1823
# 54.0     1719
# 28.0     1657
# 26.0     1392
# 56.0     1382
# 58.0     1237
# 24.0      859
# 60.0      811
# 22.0      543
# 62.0      476
# 64.0      402
# 66.0      308
# 68.0      281
# 20.0      261
# 70.0      248
# 72.0      227
# 74.0      167
# 76.0      137
# 78.0      102
# 80.0       81
# 82.0       57
# 18.0       44
# 84.0       44
# 86.0       29
# 88.0       23
# 90.0       12
# 94.0        7
# 92.0        6
# 98.0        2
# 99.0        1
# 96.0        1
# Name: count, dtype: int64
# (51047,)
# unique: 44
# null:909
# ________________________________________________________________
# AgeHH2
# 0.0     26087
# 46.0     1487
# 48.0     1419
# 44.0     1411
# 50.0     1335
# 42.0     1330
# 52.0     1295
# 40.0     1292
# 38.0     1218
# 36.0     1193
# 34.0     1131
# 32.0     1120
# 30.0     1081
# 54.0     1075
# 28.0      896
# 56.0      737
# 26.0      729
# 24.0      655
# 58.0      590
# 60.0      525
# 62.0      447
# 22.0      445
# 64.0      366
# 20.0      351
# 66.0      313
# 68.0      269
# 70.0      227
# 72.0      188
# 18.0      179
# 74.0      169
# 76.0      127
# 78.0      119
# 80.0      107
# 82.0       58
# 86.0       37
# 84.0       34
# 90.0       29
# 88.0       27
# 96.0       11
# 98.0       10
# 94.0       10
# 92.0        8
# 99.0        1
# Name: count, dtype: int64
# (51047,)
# unique: 44
# null:909
# ________________________________________________________________
# ChildrenInHH
# No     38679
# Yes    12368
# Name: count, dtype: int64
# (51047,)
# unique: 2
# null:0
# ________________________________________________________________
# HandsetRefurbished
# No     43956
# Yes     7091
# Name: count, dtype: int64
# (51047,)
# unique: 2
# null:0
# ________________________________________________________________
# HandsetWebCapable
# Yes    46046
# No      5001
# Name: count, dtype: int64
# (51047,)
# unique: 2
# null:0
# ________________________________________________________________
# TruckOwner
# No     41524
# Yes     9523
# Name: count, dtype: int64
# (51047,)
# unique: 2
# null:0
# ________________________________________________________________
# RVOwner
# No     46894
# Yes     4153
# Name: count, dtype: int64
# (51047,)
# unique: 2
# null:0
# ________________________________________________________________
# Homeownership
# Known      33987
# Unknown    17060
# Name: count, dtype: int64
# (51047,)
# unique: 2
# null:0
# ________________________________________________________________
# BuysViaMailOrder
# No     32596
# Yes    18451
# Name: count, dtype: int64
# (51047,)
# unique: 2
# null:0
# ________________________________________________________________
# RespondsToMailOffers
# No     31821
# Yes    19226
# Name: count, dtype: int64
# (51047,)
# unique: 2
# null:0
# ________________________________________________________________
# OptOutMailings
# No     50295
# Yes      752
# Name: count, dtype: int64
# (51047,)
# unique: 2
# null:0
# ________________________________________________________________
# NonUSTravel
# No     48168
# Yes     2879
# Name: count, dtype: int64
# (51047,)
# unique: 2
# null:0
# ________________________________________________________________
# OwnsComputer
# No     41583
# Yes     9464
# Name: count, dtype: int64
# (51047,)
# unique: 2
# null:0
# ________________________________________________________________
# HasCreditCard
# Yes    34503
# No     16544
# Name: count, dtype: int64
# (51047,)
# unique: 2
# null:0
# ________________________________________________________________
# RetentionCalls
# 0    49302
# 1     1609
# 2      120
# 3       14
# 4        2
# Name: count, dtype: int64
# (51047,)
# unique: 5
# null:0
# ________________________________________________________________
# RetentionOffersAccepted
# 0    50166
# 1      837
# 2       36
# 3        8
# Name: count, dtype: int64
# (51047,)
# unique: 4
# null:0
# ________________________________________________________________
# NewCellphoneUser
# No     41223
# Yes     9824
# Name: count, dtype: int64
# (51047,)
# unique: 2
# null:0
# ________________________________________________________________
# NotNewCellphoneUser
# No     44012
# Yes     7035
# Name: count, dtype: int64
# (51047,)
# unique: 2
# null:0
# ________________________________________________________________
# ReferralsMadeBySubscriber
# 0     48663
# 1      2244
# 2       100
# 3        21
# 4         6
# 6         4
# 7         2
# 5         2
# 16        1
# 11        1
# 8         1
# 9         1
# 35        1
# Name: count, dtype: int64
# (51047,)
# unique: 13
# null:0
# ________________________________________________________________
# IncomeGroup
# 0    12835
# 6     9607
# 7     5877
# 9     5563
# 5     4262
# 4     4053
# 3     2991
# 8     2622
# 1     2039
# 2     1198
# Name: count, dtype: int64
# (51047,)
# unique: 10
# null:0
# ________________________________________________________________
# OwnsMotorcycle
# No     50368
# Yes      679
# Name: count, dtype: int64
# (51047,)
# unique: 2
# null:0
# ________________________________________________________________
# AdjustmentsToCreditRating
# 0     49209
# 1      1401
# 2       248
# 3        92
# 4        34
# 5        30
# 6         8
# 8         7
# 7         6
# 9         4
# 11        3
# 10        2
# 25        1
# 21        1
# 12        1
# Name: count, dtype: int64
# (51047,)
# unique: 15
# null:0
# ________________________________________________________________
# HandsetPrice
# Unknown    28982
# 30          7328
# 150         4115
# 130         2105
# 80          1960
# 10          1928
# 60          1776
# 200         1266
# 100         1235
# 40           249
# 400           46
# 250           20
# 300           13
# 180           10
# 500            8
# 240            6
# Name: count, dtype: int64
# (51047,)
# unique: 16
# null:0
# ________________________________________________________________
# MadeCallToRetentionTeam
# No     49302
# Yes     1745
# Name: count, dtype: int64
# (51047,)
# unique: 2
# null:0
# ________________________________________________________________
# CreditRating
# 2-High       18993
# 1-Highest     8522
# 3-Good        8410
# 5-Low         6499
# 4-Medium      5357
# 7-Lowest      2114
# 6-VeryLow     1152
# Name: count, dtype: int64
# (51047,)
# unique: 7
# null:0
# ________________________________________________________________
# PrizmCode
# Other       24655
# Suburban    16378
# Town         7589
# Rural        2425
# Name: count, dtype: int64
# (51047,)
# unique: 4
# null:0
# ________________________________________________________________
# Occupation
# Other           37637
# Professional     8755
# Crafts           1519
# Clerical          986
# Self              879
# Retired           733
# Student           381
# Homemaker         157
# Name: count, dtype: int64
# (51047,)
# unique: 8
# null:0
# ________________________________________________________________
# MaritalStatus
# Unknown    19700
# Yes        18651
# No         12696
# Name: count, dtype: int64
# (51047,)
# unique: 3
# null:0
# ________________________________________________________________

# %%
print("Categorical features:", categorical)
print("________________________________________________________________")

print("Continuous features:", continuous)
# Out:
# Categorical features: ['Churn', 'UniqueSubs', 'ActiveSubs', 'HandsetModels', 'ChildrenInHH', 'HandsetRefurbished', 'HandsetWebCapable', 'TruckOwner', 'RVOwner', 'Homeownership', 'BuysViaMailOrder', 'RespondsToMailOffers', 'OptOutMailings', 'NonUSTravel', 'OwnsComputer', 'HasCreditCard', 'RetentionCalls', 'RetentionOffersAccepted', 'NewCellphoneUser', 'NotNewCellphoneUser', 'ReferralsMadeBySubscriber', 'IncomeGroup', 'OwnsMotorcycle', 'AdjustmentsToCreditRating', 'HandsetPrice', 'MadeCallToRetentionTeam', 'CreditRating', 'PrizmCode', 'Occupation', 'MaritalStatus']
# ________________________________________________________________
# Continuous features: ['MonthlyRevenue', 'MonthlyMinutes', 'TotalRecurringCharge', 'DirectorAssistedCalls', 'OverageMinutes', 'RoamingCalls', 'PercChangeMinutes', 'PercChangeRevenues', 'DroppedCalls', 'BlockedCalls', 'UnansweredCalls', 'CustomerCareCalls', 'ThreewayCalls', 'ReceivedCalls', 'OutboundCalls', 'InboundCalls', 'PeakCallsInOut', 'OffPeakCallsInOut', 'DroppedBlockedCalls', 'CallForwardingCalls', 'CallWaitingCalls', 'MonthsInService', 'ServiceArea', 'Handsets', 'CurrentEquipmentDays', 'AgeHH1', 'AgeHH2']

# %% [markdown]
# <h1>Handling Outliers</h1>

# %%
def drop_low_count_records(data, feature):
  # Get the value counts of the feature
  counts = data[feature].value_counts()
  # Get the values that have between 1 and 4 count
  low_count_values = counts[counts.between(1, 10)].index
  # Drop the records that have those values
  data = data[~data[feature].isin(low_count_values)]
  # Return the filtered data
  return data

# %%
for column in data.columns:
    data = drop_low_count_records(data, column)
    print(data[column].value_counts())
# Out:
# Churn
# No     36336
# Yes    14711
# Name: count, dtype: int64
# MonthlyRevenue
# 29.99    1069
# 34.99     806
# 10.00     469
# 30.00     404
# 49.99     392
#          ...
# 50.41      11
# 48.20      11
# 75.98      11
# 32.15      11
# 54.44      11
# Name: count, Length: 610, dtype: int64
# MonthlyMinutes
# 0.0      515
# 2.0       83
# 6.0       82
# 3.0       67
# 4.0       66
#         ...
# 502.0     11
# 381.0     11
# 514.0     11
# 366.0     11
# 455.0     11
# Name: count, Length: 446, dtype: int64
# TotalRecurringCharge
# 30.0    3832
# 45.0    2182
# 40.0    2099
# 10.0     898
# 50.0     895
# 60.0     708
# 32.0     458
# 70.0     363
# 35.0     300
# 17.0     220
# 20.0     186
# 42.0     123
# 55.0     122
# 25.0     101
# 5.0       77
# 47.0      63
# 37.0      60
# 36.0      53
# 52.0      50
# 15.0      49
# 80.0      46
# 0.0       40
# 41.0      39
# 34.0      38
# 38.0      35
# 33.0      33
# 29.0      26
# 43.0      24
# 44.0      24
# 85.0      23
# 95.0      23
# 22.0      21
# 75.0      19
# 46.0      18
# 26.0      16
# 48.0      15
# 39.0      14
# 28.0      13
# 16.0      13
# 31.0      13
# 49.0      11
# Name: count, dtype: int64
# DirectorAssistedCalls
# 0.00    9338
# 0.25    1712
# 0.50     791
# 0.74     492
# 0.99     301
# 1.24     208
# 1.49     131
# 1.73      86
# 1.98      52
# 2.48      45
# 2.23      42
# 2.97      25
# 2.72      21
# 3.22      16
# 3.96      13
# 3.46      12
# 3.71      12
# Name: count, dtype: int64
# OverageMinutes
# 0.0     10958
# 1.0       223
# 2.0       217
# 4.0       167
# 8.0        98
# 10.0       92
# 14.0       91
# 6.0        89
# 3.0        87
# 5.0        79
# 12.0       66
# 18.0       64
# 7.0        54
# 11.0       54
# 13.0       53
# 9.0        52
# 16.0       51
# 15.0       42
# 20.0       40
# 24.0       38
# 22.0       37
# 17.0       35
# 28.0       28
# 21.0       28
# 26.0       26
# 25.0       26
# 19.0       25
# 32.0       25
# 30.0       21
# 23.0       20
# 38.0       16
# 31.0       14
# 34.0       14
# 27.0       14
# 40.0       14
# 46.0       13
# 50.0       12
# 36.0       12
# 37.0       12
# 29.0       12
# 60.0       11
# 48.0       11
# 52.0       11
# Name: count, dtype: int64
# RoamingCalls
# 0.0    11010
# 0.2      336
# 0.1      289
# 0.3      222
# 0.5      127
# 0.4      111
# 0.6      104
# 0.7       82
# 1.0       61
# 0.8       56
# 0.9       54
# 1.1       51
# 1.2       39
# 1.3       36
# 1.5       27
# 1.6       24
# 1.4       24
# 2.1       18
# 1.9       17
# 1.7       16
# 2.0       16
# 2.2       15
# 2.3       15
# 1.8       14
# 2.7       13
# 2.5       11
# Name: count, dtype: int64
# PercChangeMinutes
#  0.0      679
# -2.0      215
# -4.0      173
# -8.0      169
# -6.0      159
#          ...
# -144.0     11
#  103.0     11
# -125.0     11
#  154.0     11
# -120.0     11
# Name: count, Length: 243, dtype: int64
# PercChangeRevenues
#  0.0    4424
# -0.3     982
# -0.2     833
# -0.5     435
# -0.1     330
#         ...
# -4.2      11
# -3.8      11
# -6.0      11
# -5.8      11
#  7.2      11
# Name: count, Length: 81, dtype: int64
# DroppedCalls
# 0.0     3109
# 0.3     1029
# 0.7      967
# 1.0      781
# 1.3      720
# 1.7      554
# 2.0      476
# 2.3      414
# 2.7      327
# 3.0      307
# 3.3      221
# 3.7      217
# 4.0      163
# 4.7      152
# 4.3      148
# 5.0      107
# 5.3       97
# 6.3       83
# 6.0       80
# 5.7       75
# 7.7       66
# 7.0       64
# 7.3       61
# 6.7       60
# 8.3       37
# 8.0       35
# 8.7       34
# 10.0      28
# 9.0       27
# 9.3       27
# 11.0      20
# 9.7       18
# 10.7      15
# 11.3      15
# 11.7      13
# 12.0      13
# 10.3      13
# Name: count, dtype: int64
# BlockedCalls
# 0.0     4750
# 0.3     1357
# 0.7      997
# 1.0      562
# 1.3      530
# 1.7      355
# 2.0      276
# 2.3      245
# 2.7      205
# 3.0      152
# 3.3      141
# 3.7      105
# 4.0       87
# 4.3       77
# 4.7       75
# 5.0       58
# 5.3       51
# 6.0       43
# 5.7       40
# 6.7       38
# 6.3       36
# 8.3       24
# 7.3       24
# 7.7       23
# 7.0       19
# 8.7       16
# 9.7       15
# 10.0      15
# 9.0       15
# 10.3      14
# 10.7      13
# 8.0       12
# 12.3      12
# Name: count, dtype: int64
# UnansweredCalls
# 0.0     1866
# 0.7      280
# 1.3      276
# 0.3      265
# 2.7      233
#         ...
# 35.3      11
# 33.0      11
# 35.0      11
# 30.3      11
# 32.7      11
# Name: count, Length: 102, dtype: int64
# CustomerCareCalls
# 0.0    8109
# 0.3     538
# 0.7     354
# 1.0     165
# 1.3     139
# 1.7     123
# 2.0      95
# 2.3      60
# 2.7      60
# 3.0      49
# 3.3      36
# 4.0      35
# 3.7      31
# 5.0      24
# 5.3      22
# 4.7      17
# 4.3      17
# 7.0      14
# 6.0      13
# 6.3      12
# Name: count, dtype: int64
# ThreewayCalls
# 0.0    8704
# 0.3     706
# 0.7     298
# 1.0      96
# 1.3      46
# 2.0      15
# 1.7      15
# 2.3      11
# Name: count, dtype: int64
# ReceivedCalls
# 0.0     2600
# 0.1      141
# 0.2       96
# 0.6       82
# 0.3       80
#         ...
# 15.5      11
# 23.2      11
# 17.9      11
# 19.8      11
# 5.9       11
# Name: count, Length: 184, dtype: int64
# OutboundCalls
# 0.0     2502
# 0.3      391
# 0.7      360
# 1.0      258
# 1.7      232
# 1.3      228
# 2.0      205
# 2.3      163
# 2.7      162
# 3.0      145
# 3.3      127
# 4.0      124
# 3.7      120
# 4.3      116
# 4.7      100
# 6.0       88
# 5.0       85
# 5.3       84
# 5.7       79
# 6.3       76
# 6.7       71
# 7.0       66
# 7.7       55
# 7.3       53
# 8.0       53
# 8.3       52
# 8.7       45
# 9.0       44
# 9.7       40
# 11.7      40
# 10.0      39
# 11.0      35
# 9.3       34
# 10.3      34
# 11.3      30
# 10.7      27
# 12.7      24
# 14.3      23
# 12.3      22
# 12.0      21
# 13.3      20
# 14.0      18
# 13.7      15
# 15.0      15
# 13.0      13
# 16.3      12
# 18.3      11
# 15.3      11
# 14.7      11
# Name: count, dtype: int64
# InboundCalls
# 0.0    4679
# 0.3     523
# 0.7     355
# 1.0     181
# 1.3     163
# 1.7     139
# 2.0      94
# 3.0      70
# 2.7      70
# 2.3      63
# 3.3      33
# 4.0      32
# 3.7      25
# 4.3      25
# 5.0      18
# 4.7      15
# 5.3      15
# 5.7      12
# 6.3      11
# 6.0      11
# Name: count, dtype: int64
# PeakCallsInOut
# 0.0     1525
# 0.7       88
# 0.3       84
# 1.3       79
# 2.7       78
#         ...
# 32.7      13
# 39.3      13
# 36.0      12
# 33.3      12
# 38.0      12
# Name: count, Length: 120, dtype: int64
# OffPeakCallsInOut
# 0.0     1695
# 0.7      170
# 0.3      160
# 1.3      135
# 1.0      129
#         ...
# 21.7      13
# 22.3      12
# 25.3      12
# 26.0      12
# 23.7      12
# Name: count, Length: 72, dtype: int64
# DroppedBlockedCalls
# 0.0    2205
# 0.3     550
# 0.7     523
# 1.3     397
# 1.0     375
# 1.7     264
# 2.0     253
# 2.3     215
# 2.7     155
# 3.0     146
# 3.3     140
# 3.7      85
# 4.0      81
# 4.7      64
# 4.3      59
# 5.0      58
# 5.3      41
# 6.0      30
# 6.3      27
# 7.7      25
# 6.7      24
# 7.3      22
# 5.7      18
# 7.0      14
# 8.3      13
# 8.0      11
# 9.0      11
# Name: count, dtype: int64
# CallForwardingCalls
# 0.0    5804
# Name: count, dtype: int64
# CallWaitingCalls
# 0.0    5475
# 0.3     252
# 0.7      64
# Name: count, dtype: int64
# MonthsInService
# 11    411
# 12    321
# 13    321
# 14    287
# 21    268
# 10    261
# 19    247
# 9     223
# 23    219
# 8     209
# 7     194
# 15    190
# 16    184
# 25    181
# 17    178
# 24    171
# 18    167
# 22    152
# 26    138
# 20    133
# 29    123
# 27    119
# 31    112
# 30    100
# 33     97
# 32     94
# 28     85
# 35     73
# 34     70
# 37     66
# 36     58
# 6      47
# 38     32
# 39     29
# 43     29
# 41     26
# 40     25
# 45     20
# 44     16
# 42     15
# 47     13
# 46     13
# 49     13
# Name: count, dtype: int64
# UniqueSubs
# 1    3519
# 2    1648
# 3     354
# 4     138
# 5      40
# 6      21
# Name: count, dtype: int64
# ActiveSubs
# 1    3902
# 2    1531
# 3     212
# 4      60
# 5      11
# Name: count, dtype: int64
# ServiceArea
# DALDAL214    132
# NYCBRO917    132
# HOUHOU281     99
# APCFCH703     96
# DALFTW817     93
#             ...
# DENBOU303     11
# LAXBEV310     11
# NEVENC760     11
# ATLMEM901     11
# PHXSCO480     11
# Name: count, Length: 149, dtype: int64
# Handsets
# 1.0    3477
# 2.0     746
# 3.0     213
# 4.0      67
# 5.0      23
# 6.0      11
# Name: count, dtype: int64
# HandsetModels
# 1.0    3711
# 2.0     665
# 3.0     129
# 4.0      29
# Name: count, dtype: int64
# CurrentEquipmentDays
# 334.0    19
# 351.0    16
# 371.0    15
# 411.0    15
# 568.0    14
#          ..
# 400.0    11
# 674.0    11
# 630.0    11
# 735.0    11
# 431.0    11
# Name: count, Length: 61, dtype: int64
# AgeHH1
# 0.0     146
# 54.0     40
# 40.0     33
# 56.0     33
# 48.0     32
# 52.0     32
# 32.0     31
# 50.0     29
# 58.0     27
# 44.0     27
# 46.0     26
# 42.0     24
# 36.0     24
# 28.0     24
# 60.0     23
# 38.0     23
# 30.0     23
# 34.0     20
# 64.0     19
# 26.0     15
# 62.0     14
# 66.0     11
# Name: count, dtype: int64
# AgeHH2
# 0.0     288
# 52.0     34
# 48.0     25
# 46.0     23
# 44.0     22
# 40.0     21
# 50.0     20
# 56.0     20
# 58.0     19
# 54.0     19
# 60.0     18
# 28.0     16
# 32.0     16
# 34.0     15
# 26.0     14
# 42.0     14
# 62.0     13
# 30.0     12
# 38.0     11
# Name: count, dtype: int64
# ChildrenInHH
# No     467
# Yes    169
# Name: count, dtype: int64
# HandsetRefurbished
# No     581
# Yes     55
# Name: count, dtype: int64
# HandsetWebCapable
# Yes    577
# No      59
# Name: count, dtype: int64
# TruckOwner
# No     520
# Yes    116
# Name: count, dtype: int64
# RVOwner
# No     573
# Yes     63
# Name: count, dtype: int64
# Homeownership
# Known      458
# Unknown    178
# Name: count, dtype: int64
# BuysViaMailOrder
# No     337
# Yes    299
# Name: count, dtype: int64
# RespondsToMailOffers
# No     330
# Yes    306
# Name: count, dtype: int64
# OptOutMailings
# No    626
# Name: count, dtype: int64
# NonUSTravel
# No     584
# Yes     42
# Name: count, dtype: int64
# OwnsComputer
# No     477
# Yes    149
# Name: count, dtype: int64
# HasCreditCard
# Yes    445
# No     181
# Name: count, dtype: int64
# RetentionCalls
# 0    616
# Name: count, dtype: int64
# RetentionOffersAccepted
# 0    616
# Name: count, dtype: int64
# NewCellphoneUser
# No     516
# Yes    100
# Name: count, dtype: int64
# NotNewCellphoneUser
# No     554
# Yes     62
# Name: count, dtype: int64
# ReferralsMadeBySubscriber
# 0    597
# 1     18
# Name: count, dtype: int64
# IncomeGroup
# 0    140
# 6    114
# 9    110
# 7     74
# 5     56
# 4     37
# 8     37
# 3     30
# 1     14
# Name: count, dtype: int64
# OwnsMotorcycle
# No    602
# Name: count, dtype: int64
# AdjustmentsToCreditRating
# 0    597
# Name: count, dtype: int64
# HandsetPrice
# Unknown    486
# 30          49
# 150         19
# 10          12
# 60          11
# Name: count, dtype: int64
# MadeCallToRetentionTeam
# No    577
# Name: count, dtype: int64
# CreditRating
# 2-High       358
# 3-Good        72
# 1-Highest     57
# 4-Medium      35
# 5-Low         31
# 7-Lowest      15
# Name: count, dtype: int64
# PrizmCode
# Other       220
# Suburban    217
# Town         99
# Rural        32
# Name: count, dtype: int64
# Occupation
# Other           377
# Professional    142
# Crafts           15
# Self             11
# Name: count, dtype: int64
# MaritalStatus
# Yes        246
# Unknown    196
# No         103
# Name: count, dtype: int64

# %% [markdown]
# <h1>Handling Null Values</h1>

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats

# Define a function to check the percentage of null values in a column
def null_percent(col):
  return col.isnull().sum() / len(col) * 100

# Define a function to check the normality of a column using Shapiro-Wilk test
def is_normal(col):
  # Null hypothesis: the column is normally distributed
  # Alternative hypothesis: the column is not normally distributed
  # Significance level: 0.05
  stat, p = stats.shapiro(col.dropna())
  return p > 0.05

# Loop through each column in the data frame
for col in data.columns:
  # Get the percentage of null values in the column
  percent = null_percent(data[col])
  # If the percentage is greater than or equal to 60, drop the column
  if percent >= 60:
    data.drop(col, axis=1, inplace=True)
  # If the percentage is between 60 and 20, fill the column with some value
  elif 20 < percent < 60:
    # If the column is numerical, check its normality
    if col in continous:
      # If the column is normal, fill with mean
      if is_normal(data[col]):
        data[col].fillna(data[col].mean(), inplace=True)
      # If the column is not normal, fill with median
      else:
        data[col].fillna(data[col].median(), inplace=True)
    # If the column is categorical, fill with mode
    elif col in categorical:
      data[col].fillna(data[col].mode()[0], inplace=True)
  # If the percentage is less than or equal to 20, drop the rows with null values
  elif percent <= 20:
    data.dropna(subset=[col], inplace=True)

# %%
for col in data.columns:
    print(f"{col, data[column].isnull().sum()}")
# Out:
# ('Churn', 0)
# ('MonthlyRevenue', 0)
# ('MonthlyMinutes', 0)
# ('TotalRecurringCharge', 0)
# ('DirectorAssistedCalls', 0)
# ('OverageMinutes', 0)
# ('RoamingCalls', 0)
# ('PercChangeMinutes', 0)
# ('PercChangeRevenues', 0)
# ('DroppedCalls', 0)
# ('BlockedCalls', 0)
# ('UnansweredCalls', 0)
# ('CustomerCareCalls', 0)
# ('ThreewayCalls', 0)
# ('ReceivedCalls', 0)
# ('OutboundCalls', 0)
# ('InboundCalls', 0)
# ('PeakCallsInOut', 0)
# ('OffPeakCallsInOut', 0)
# ('DroppedBlockedCalls', 0)
# ('CallForwardingCalls', 0)
# ('CallWaitingCalls', 0)
# ('MonthsInService', 0)
# ('UniqueSubs', 0)
# ('ActiveSubs', 0)
# ('ServiceArea', 0)
# ('Handsets', 0)
# ('HandsetModels', 0)
# ('CurrentEquipmentDays', 0)
# ('AgeHH1', 0)
# ('AgeHH2', 0)
# ('ChildrenInHH', 0)
# ('HandsetRefurbished', 0)
# ('HandsetWebCapable', 0)
# ('TruckOwner', 0)
# ('RVOwner', 0)
# ('Homeownership', 0)
# ('BuysViaMailOrder', 0)
# ('RespondsToMailOffers', 0)
# ('OptOutMailings', 0)
# ('NonUSTravel', 0)
# ('OwnsComputer', 0)
# ('HasCreditCard', 0)
# ('RetentionCalls', 0)
# ('RetentionOffersAccepted', 0)
# ('NewCellphoneUser', 0)
# ('NotNewCellphoneUser', 0)
# ('ReferralsMadeBySubscriber', 0)
# ('IncomeGroup', 0)
# ('OwnsMotorcycle', 0)
# ('AdjustmentsToCreditRating', 0)
# ('HandsetPrice', 0)
# ('MadeCallToRetentionTeam', 0)
# ('CreditRating', 0)
# ('PrizmCode', 0)
# ('Occupation', 0)
# ('MaritalStatus', 0)

# %%
data.head()
# Out:
#            Churn  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# CustomerID
# 3003602       No           40.35            78.0                  50.0
# 3005870       No           50.45           120.0                  50.0
# 3014974       No           32.01           168.0                  30.0
# 3015198       No           40.09            58.0                  50.0
# 3015518      Yes           29.99             0.0                  30.0
#
#             DirectorAssistedCalls  OverageMinutes  RoamingCalls  \
# CustomerID
# 3003602                      0.00             0.0           0.0
# 3005870                      0.00             0.0           0.0
# 3014974                      0.25             1.0           0.0
# 3015198                      0.00             0.0           0.0
# 3015518                      0.00             0.0           0.0
#
#             PercChangeMinutes  PercChangeRevenues  DroppedCalls  ...  \
# CustomerID                                                       ...
# 3003602                  30.0                -0.4           0.0  ...
# 3005870                   8.0                -0.4           3.0  ...
# 3014974                 -86.0                -1.0           4.7  ...
# 3015198                  18.0                 0.3           4.7  ...
# 3015518                   0.0                 0.0           0.0  ...
#
#             ReferralsMadeBySubscriber  IncomeGroup  OwnsMotorcycle  \
# CustomerID
# 3003602                             0            3              No
# 3005870                             0            9              No
# 3014974                             0            6              No
# 3015198                             0            4              No
# 3015518                             0            9              No
#
#             AdjustmentsToCreditRating  HandsetPrice  MadeCallToRetentionTeam  \
# CustomerID
# 3003602                             0            30                       No
# 3005870                             0            30                       No
# 3014974                             0            30                       No
# 3015198                             0            30                       No
# 3015518                             0            30                       No
#
#             CreditRating  PrizmCode    Occupation  MaritalStatus
# CustomerID
# 3003602         4-Medium      Rural         Other             No
# 3005870        1-Highest   Suburban         Other            Yes
# 3014974        1-Highest      Other         Other        Unknown
# 3015198            5-Low       Town  Professional            Yes
# 3015518        1-Highest   Suburban         Other             No
#
# [5 rows x 57 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 532 entries, 3003602 to 3397650
# Data columns (total 57 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Churn                      532 non-null    object
#  1   MonthlyRevenue             532 non-null    float64
#  2   MonthlyMinutes             532 non-null    float64
#  3   TotalRecurringCharge       532 non-null    float64
#  4   DirectorAssistedCalls      532 non-null    float64
#  5   OverageMinutes             532 non-null    float64
#  6   RoamingCalls               532 non-null    float64
#  7   PercChangeMinutes          532 non-null    float64
#  8   PercChangeRevenues         532 non-null    float64
#  9   DroppedCalls               532 non-null    float64
#  10  BlockedCalls               532 non-null    float64
#  11  UnansweredCalls            532 non-null    float64
#  12  CustomerCareCalls          532 non-null    float64
#  13  ThreewayCalls              532 non-null    float64
#  14  ReceivedCalls              532 non-null    float64
#  15  OutboundCalls              532 non-null    float64
#  16  InboundCalls               532 non-null    float64
#  17  PeakCallsInOut             532 non-null    float64
#  18  OffPeakCallsInOut          532 non-null    float64
#  19  DroppedBlockedCalls        532 non-null    float64
#  20  CallForwardingCalls        532 non-null    float64
#  21  CallWaitingCalls           532 non-null    float64
#  22  MonthsInService            532 non-null    int64
#  23  UniqueSubs                 532 non-null    int64
#  24  ActiveSubs                 532 non-null    int64
#  25  ServiceArea                532 non-null    object
#  26  Handsets                   532 non-null    float64
#  27  HandsetModels              532 non-null    float64
#  28  CurrentEquipmentDays       532 non-null    float64
#  29  AgeHH1                     532 non-null    float64
#  30  AgeHH2                     532 non-null    float64
#  31  ChildrenInHH               532 non-null    object
#  32  HandsetRefurbished         532 non-null    object
#  33  HandsetWebCapable          532 non-null    object
#  34  TruckOwner                 532 non-null    object
#  35  RVOwner                    532 non-null    object
#  36  Homeownership              532 non-null    object
#  37  BuysViaMailOrder           532 non-null    object
#  38  RespondsToMailOffers       532 non-null    object
#  39  OptOutMailings             532 non-null    object
#  40  NonUSTravel                532 non-null    object
#  41  OwnsComputer               532 non-null    object
#  42  HasCreditCard              532 non-null    object
#  43  RetentionCalls             532 non-null    int64
#  44  RetentionOffersAccepted    532 non-null    int64
#  45  NewCellphoneUser           532 non-null    object
#  46  NotNewCellphoneUser        532 non-null    object
#  47  ReferralsMadeBySubscriber  532 non-null    int64
#  48  IncomeGroup                532 non-null    int64
#  49  OwnsMotorcycle             532 non-null    object
#  50  AdjustmentsToCreditRating  532 non-null    int64
#  51  HandsetPrice               532 non-null    object
#  52  MadeCallToRetentionTeam    532 non-null    object
#  53  CreditRating               532 non-null    object
#  54  PrizmCode                  532 non-null    object
#  55  Occupation                 532 non-null    object
#  56  MaritalStatus              532 non-null    object
# dtypes: float64(26), int64(8), object(23)
# memory usage: 257.2+ KB

# %%
categorical
# Out:
# ['Churn',
#  'UniqueSubs',
#  'ActiveSubs',
#  'HandsetModels',
#  'ChildrenInHH',
#  'HandsetRefurbished',
#  'HandsetWebCapable',
#  'TruckOwner',
#  'RVOwner',
#  'Homeownership',
#  'BuysViaMailOrder',
#  'RespondsToMailOffers',
#  'OptOutMailings',
#  'NonUSTravel',
#  'OwnsComputer',
#  'HasCreditCard',
#  'RetentionCalls',
#  'RetentionOffersAccepted',
#  'NewCellphoneUser',
#  'NotNewCellphoneUser',
#  'ReferralsMadeBySubscriber',
#  'IncomeGroup',
#  'OwnsMotorcycle',
#  'AdjustmentsToCreditRating',
#  'HandsetPrice',
#  'MadeCallToRetentionTeam',
#  'CreditRating',
#  'PrizmCode',
#  'Occupation',
#  'MaritalStatus']

# %%
from sklearn.preprocessing import LabelBinarizer


lb = LabelBinarizer()

# Fit label binarizer to the data
lb.fit(data[categorical])

# Check the classes
lb.classes_
# array(['blue', 'green', 'red', 'yellow'], dtype='<U6')

# Transform labels to binary vectors
lb.transform(data[categorical])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 7
#       4 lb = LabelBinarizer()
#       6 # Fit label binarizer to the data
# ----> 7 lb.fit(data[categorical])
#       9 # Check the classes
#      10 lb.classes_
#
# File ~\miniconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\miniconda3\Lib\site-packages\sklearn\preprocessing\_label.py:296, in LabelBinarizer.fit(self, y)
#     289 if self.sparse_output and (self.pos_label == 0 or self.neg_label != 0):
#     290     raise ValueError(
#     291         "Sparse binarization is only supported with non "
#     292         "zero pos_label and zero neg_label, got "
#     293         f"pos_label={self.pos_label} and neg_label={self.neg_label}"
#     294     )
# --> 296 self.y_type_ = type_of_target(y, input_name="y")
#     298 if "multioutput" in self.y_type_:
#     299     raise ValueError(
#     300         "Multioutput target data is not supported with label binarization"
#     301     )
#
# File ~\miniconda3\Lib\site-packages\sklearn\utils\multiclass.py:310, in type_of_target(y, input_name)
#     307 if sparse_pandas:
#     308     raise ValueError("y cannot be class 'SparseSeries' or 'SparseArray'")
# --> 310 if is_multilabel(y):
#     311     return "multilabel-indicator"
#     313 # DeprecationWarning will be replaced by ValueError, see NEP 34
#     314 # https://numpy.org/neps/nep-0034-infer-dtype-is-object.html
#     315 # We therefore catch both deprecation (NumPy < 1.24) warning and
#     316 # value error (NumPy >= 1.24).
#
# File ~\miniconda3\Lib\site-packages\sklearn\utils\multiclass.py:188, in is_multilabel(y)
#     182     return (
#     183         len(y.data) == 0
#     184         or (labels.size == 1 or (labels.size == 2) and (0 in labels))
#     185         and (y.dtype.kind in "biu" or _is_integral_float(labels))  # bool, int, uint
#     186     )
#     187 else:
# --> 188     labels = xp.unique_values(y)
#     190     return len(labels) < 3 and (
#     191         y.dtype.kind in "biu" or _is_integral_float(labels)  # bool, int, uint
#     192     )
#
# File ~\miniconda3\Lib\site-packages\sklearn\utils\_array_api.py:262, in _NumPyAPIWrapper.unique_values(self, x)
#     261 def unique_values(self, x):
# --> 262     return numpy.unique(x)
#
# File <__array_function__ internals>:200, in unique(*args, **kwargs)
#
# File ~\miniconda3\Lib\site-packages\numpy\lib\arraysetops.py:274, in unique(ar, return_index, return_inverse, return_counts, axis, equal_nan)
#     272 ar = np.asanyarray(ar)
#     273 if axis is None:
# --> 274     ret = _unique1d(ar, return_index, return_inverse, return_counts,
#     275                     equal_nan=equal_nan)
#     276     return _unpack_tuple(ret)
#     278 # axis was specified and not None
#
# File ~\miniconda3\Lib\site-packages\numpy\lib\arraysetops.py:336, in _unique1d(ar, return_index, return_inverse, return_counts, equal_nan)
#     334     aux = ar[perm]
#     335 else:
# --> 336     ar.sort()
#     337     aux = ar
#     338 mask = np.empty(aux.shape, dtype=np.bool_)
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def gbp(feature): 
    
    plt.figure(figsize=(10, 6))
    
    # Create a grouped bar plot
    upsample(data, feature)
    sns.countplot(x='Churn', hue=feature, data=data.astype(str))
    
    plt.xlabel('Churn Values')
    plt.ylabel('Count')
    plt.title(f'Grouped Bar Plot of Churn vs {feature} ')
    plt.legend(title=f'feature')
    plt.show()


for cols in data.columns:
    if data[cols].dtype =='category':
        
        print(data[cols].dtype)
        print(cols)
        gbp(cols)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have a DataFrame called 'data' with columns 'Churn' and 'MadeCallToRetentionTeam'
# Replace these with your actual column names

# Group and calculate percentage
counts = data.groupby(["Churn", "MadeCallToRetentionTeam"]).size()
percentages = counts / counts.groupby(level=0).sum()
percentages = percentages.reset_index(name="percentage")

# Pivot the DataFrame for better visualization
pivot_df = percentages.pivot(index='Churn', columns='MadeCallToRetentionTeam', values='percentage')

# Plot stacked bar chart
ax = pivot_df.plot(kind='bar', stacked=True, figsize=(8, 6), colormap="viridis")

# Set labels and title
plt.xlabel('Churn')
plt.ylabel('Percentage')
plt.title('Percentage of customers who made a call to the retention team by churn')

# Display percentages on top of the bars
for col in pivot_df.columns:
    for i, val in enumerate(pivot_df[col]):
        ax.text(i, val / 2, f'{val:.1%}', ha='center', va='center', color='white')

# Show legend
plt.legend(title='MadeCallToRetentionTeam')

plt.show()

# %%
import pandas as pd

def encode_and_concatenate(df, columns):
    # Perform one-hot encoding
    encoded_cols = pd.get_dummies(df[columns], prefix=columns)

    # Concatenate the one-hot encoded columns to the original DataFrame
    df = pd.concat([df, encoded_cols], axis=1)

    # Convert boolean values to integers and concatenate them
    df[f'{columns}_Encoded'] = encoded_cols.astype(np.int64).apply(lambda row: ''.join(map(str, row)), axis=1)

    # Convert the concatenated string to int
    df[f'{columns}_Encoded'] = df[f'{columns}_Encoded'].astype(int)

    # Drop the individual boolean columns
    df.drop(columns=encoded_cols.columns, inplace=True)

    return df

# %%
# Apply the function for each set of boolean columns
boolean_columns = data[categorical]

for column in boolean_columns:
    data = encode_and_concatenate(data, column)

# %%
for column in data.columns:
    if data.dtypes[column] == 'category' or 'bool':
        # Perform one-hot encoding
        encoded_cols = pd.get_dummies(data[column], prefix=column)
        
        # Concatenate the one-hot encoded columns to the original DataFrame
        data = pd.concat([data, encoded_cols], axis=1)
        data[f'{column}_Encoded'] = encoded_cols.astype(int).apply(lambda row: ''.join(map(str, row)), axis=1)
